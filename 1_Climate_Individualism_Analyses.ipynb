# %% [markdown]
# ## Analyses scripts for the manuscript "Cultural Individualism/Collectivism Moderates the Effects of Climate Action Interventions"

# %% [markdown]
# ### Install Libraries

# %%
# Core analysis packages
import numpy as np
import os, sys
import pandas as pd
from scipy import stats
from scipy.special import comb
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats import anova
import bff
import matplotlib.pyplot as plt
plt.rcdefaults()
import seaborn as sns 
sns.set(style="ticks", color_codes=True)
sns.set_style("white")
sns.set_style({'xtick.bottom': True, 'ytick.left': True})
colorref = ["gray", "royalblue", "crimson", "goldenrod", "mediumorchid", "seagreen"]

# iPython magic commands
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# %autosave 30

SMALL_SIZE = 12
MEDIUM_SIZE = 12
BIG_SIZE = 14

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIG_SIZE)  # fontsize of the figure title
cust_palette = sns.color_palette("Paired")[6:10]
cust_palette = [cust_palette[i] for i in [1,0,3,2]]

def median_split(S):
    return S > S.median()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 30 seconds

# %% [markdown]
# ### Import data and run data preprocessing

# %%
df = pd.read_excel("data63.xlsx")
df
# Out:
#               ResponseId  Country  cond          condName  \
# 0      R_1r7Yr7R1xMimIvj      usa     5     CollectAction
# 1      R_2ATgV5VxewrTRiI      usa     1           Control
# 2      R_3ENlePBlLyYjExr      usa     9   LetterFutureGen
# 3      R_2c0HQgvYzas6mus      usa     4        SciConsens
# 4      R_00siryCwgdMus6J      usa     8   PluralIgnorance
# ...                  ...      ...   ...               ...
# 59435  R_2TuXye2HP6EO5KZ  vietnam    11    FutureSelfCont
# 59436  R_3R3p8C0gzLKTcCu  vietnam    12      BindingMoral
# 59437  R_OeT1JV3yC1aJ4EF  vietnam     8   PluralIgnorance
# 59438  R_2azVf0KXD3rtly8  vietnam     3  NegativeEmotions
# 59439  R_3j0DcbTReKZgR9O  vietnam     1           Control
#
#                                       Intervention_order  Belief1  Belief2  \
# 0      BeliefinAnthrCC|SocialmediasharingPipedText|Po...     98.0     77.0
# 1      PolicySupport|BeliefinAnthrCC|Socialmediashari...     49.0     50.0
# 2      SocialmediasharingPipedText|PolicySupport|Beli...     87.0     82.0
# 3      PolicySupport|SocialmediasharingPipedText|Beli...      1.0      1.0
# 4      BeliefinAnthrCC|SocialmediasharingPipedText|Po...     56.0     59.0
# ...                                                  ...      ...      ...
# 59435  PolicySupport|SocialmediasharingPipedText|Beli...     49.0    100.0
# 59436  BeliefinAnthrCC|SocialmediasharingPipedText|Po...     94.0     98.0
# 59437  SocialmediasharingPipedText|PolicySupport|Beli...    100.0    100.0
# 59438  SocialmediasharingPipedText|BeliefinAnthrCC|Po...     79.0     51.0
# 59439  PolicySupport|BeliefinAnthrCC|Socialmediashari...    100.0    100.0
#
#        Belief3  Belief4  Policy1  ...  Edu  Income   Indirect_SES  \
# 0         86.0     93.0     71.0  ...  3.0     5.0          2,4,5
# 1         51.0     51.0      1.0  ...  3.0     4.0  1,2,3,4,5,6,7
# 2         84.0     83.0     84.0  ...  3.0     5.0      1,2,3,6,7
# 3          0.0      0.0      1.0  ...  3.0     5.0  1,2,3,4,5,6,7
# 4         61.0     54.0     79.0  ...  3.0     5.0      1,3,5,6,7
# ...        ...      ...      ...  ...  ...     ...            ...
# 59435    100.0     74.0     70.0  ...  3.0     2.0  1,2,3,4,5,6,7
# 59436     98.0     96.0     92.0  ...  3.0     2.0      1,2,4,6,7
# 59437    100.0    100.0     80.0  ...  3.0     1.0      2,4,5,6,7
# 59438     78.0     51.0      0.0  ...  3.0     NaN  1,2,3,4,5,6,7
# 59439    100.0    100.0     75.0  ...  3.0     5.0        1,4,5,6
#
#        MacArthur_SES  PerceivedSciConsensu_1  Intro_Timer  \
# 0                7.0                    80.0        6.056
# 1                5.0                    51.0       16.284
# 2                8.0                    73.0        5.701
# 3                4.0                     1.0       13.282
# 4                7.0                    65.0        8.474
# ...              ...                     ...          ...
# 59435            7.0                    60.0       27.732
# 59436            3.0                    74.0       49.502
# 59437            6.0                   100.0        7.920
# 59438            7.0                   100.0       40.222
# 59439            6.0                    69.0       26.443
#
#        condition_time_total  WEPTcc  BELIEFcc   POLICYcc
# 0                    95.501       1     88.50  89.000000
# 1                   200.742       0     50.25  66.222222
# 2                   218.442       1     84.00  84.222222
# 3                    12.702       0      0.50   1.222222
# 4                    19.315       0     57.50  80.222222
# ...                     ...     ...       ...        ...
# 59435               873.538       0     80.75  82.500000
# 59436                 0.000       0     96.50  86.444444
# 59437                89.072       7    100.00  83.333333
# 59438               398.193       8     64.75  66.666667
# 59439               245.602       8    100.00  62.000000
#
# [59440 rows x 62 columns]

# %%
# Global median split
# df["Ideology"] = (df["Politics2_1"] > df["Politics2_1"].median()).astype(int)

df['ide'] = (df['Politics2_1'] + df['Politics2_9'])/2

# Per-country median split
new = []
for _, sub in df.groupby("Country"):
    sub.loc[:, "Ideology"] = (sub.loc[:, "ide"] > sub.loc[:, "ide"].median()).astype(float)
    # Ensure NaN ideology when Politics2_1 is NaN
    sub.loc[sub.Politics2_1.isna(), "Ideology"] = np.NaN
    new.append(sub)
df = pd.concat(new)
# Replace 1 with "Conservative" and 0 with "Liberal"
df['Ideology'] = df['Ideology'].replace(1, 'Conservative').replace(0, 'Liberal')

# %%
#load predictor dataframe
predictordata = pd.read_excel("PredictorData.xlsx")
predictordata
# Out:
#                Country        GDP     CRI   EPI  PostmaterialistIndex  \
# 0              algeria    163.138  105.17  29.6                  2.00
# 1              armenia     13.861   98.17  48.3                  1.19
# 2            australia   1701.893   28.00  60.1                  1.95
# 3              austria    471.685   56.83  66.5                   NaN
# 4           azerbaijan     54.622  118.00  38.6                   NaN
# ..                 ...        ...     ...   ...                   ...
# 59  unitedarabemirates    415.022  118.00  52.4                   NaN
# 60             uruguay     59.321   79.67  37.4                  2.45
# 61                 usa  25464.475     NaN  51.1                  1.94
# 62           venezuela    102.020  118.00  46.4                   NaN
# 63             vietnam    406.452   50.17  20.1                   NaN
#
#     PowerDistanceHI  IndividualismHI  MasculinityHI  UncertaintyAvoidanceHI  \
# 0              80.0               35           35.0                    70.0
# 1              85.0               22           50.0                    88.0
# 2              38.0               90           61.0                    51.0
# 3              11.0               55           79.0                    70.0
# 4              85.0               22           50.0                    88.0
# ..              ...              ...            ...                     ...
# 59             74.0               36           52.0                    66.0
# 60             61.0               36           38.0                    98.0
# 61             40.0               91           62.0                    46.0
# 62             81.0               12           73.0                    76.0
# 63             70.0               20           40.0                    30.0
#
#     LongTermOrientationHI  IndulgenceHI Notes
# 0                    26.0          32.0   NaN
# 1                    61.0          25.0   NaN
# 2                    21.0          71.0   NaN
# 3                    60.0          63.0   NaN
# 4                    61.0          22.0   NaN
# ..                    ...           ...   ...
# 59                   22.0          22.0   NaN
# 60                   26.0          53.0   NaN
# 61                   26.0          68.0   NaN
# 62                   16.0         100.0   NaN
# 63                   57.0          35.0   NaN
#
# [64 rows x 12 columns]

# %%
#merge main dataframe with predictor data & wvs survey data
df = df.merge(predictordata, on='Country', how='left')
df
# Out:
#               ResponseId  Country  cond          condName  \
# 0      R_1DNJsF7DGNuIb9e  algeria     4        SciConsens
# 1      R_3KOO2oUWQNtKzrD  algeria     8   PluralIgnorance
# 2      R_3OdqhjO2quQKaIx  algeria    12      BindingMoral
# 3      R_2QuK4DRmnWL9FXS  algeria    10       DynamicNorm
# 4      R_1DYkviJgtp5u6JV  algeria     7     PsychDistance
# ...                  ...      ...   ...               ...
# 59435  R_2TuXye2HP6EO5KZ  vietnam    11    FutureSelfCont
# 59436  R_3R3p8C0gzLKTcCu  vietnam    12      BindingMoral
# 59437  R_OeT1JV3yC1aJ4EF  vietnam     8   PluralIgnorance
# 59438  R_2azVf0KXD3rtly8  vietnam     3  NegativeEmotions
# 59439  R_3j0DcbTReKZgR9O  vietnam     1           Control
#
#                                       Intervention_order  Belief1  Belief2  \
# 0      PolicySupport|BeliefinAnthrCC|Socialmediashari...     50.0     50.0
# 1      PolicySupport|SocialmediasharingPipedText|Beli...    100.0    100.0
# 2      BeliefinAnthrCC|SocialmediasharingPipedText|Po...     93.0     67.0
# 3      SocialmediasharingPipedText|BeliefinAnthrCC|Po...      NaN      3.0
# 4      SocialmediasharingPipedText|BeliefinAnthrCC|Po...     68.0    100.0
# ...                                                  ...      ...      ...
# 59435  PolicySupport|SocialmediasharingPipedText|Beli...     49.0    100.0
# 59436  BeliefinAnthrCC|SocialmediasharingPipedText|Po...     94.0     98.0
# 59437  SocialmediasharingPipedText|PolicySupport|Beli...    100.0    100.0
# 59438  SocialmediasharingPipedText|BeliefinAnthrCC|Po...     79.0     51.0
# 59439  PolicySupport|BeliefinAnthrCC|Socialmediashari...    100.0    100.0
#
#        Belief3  Belief4  Policy1  ...     CRI   EPI  PostmaterialistIndex  \
# 0         53.0     53.0     66.0  ...  105.17  29.6                   2.0
# 1        100.0    100.0      1.0  ...  105.17  29.6                   2.0
# 2        100.0     33.0     15.0  ...  105.17  29.6                   2.0
# 3          NaN      NaN      0.0  ...  105.17  29.6                   2.0
# 4        100.0     95.0     70.0  ...  105.17  29.6                   2.0
# ...        ...      ...      ...  ...     ...   ...                   ...
# 59435    100.0     74.0     70.0  ...   50.17  20.1                   NaN
# 59436     98.0     96.0     92.0  ...   50.17  20.1                   NaN
# 59437    100.0    100.0     80.0  ...   50.17  20.1                   NaN
# 59438     78.0     51.0      0.0  ...   50.17  20.1                   NaN
# 59439    100.0    100.0     75.0  ...   50.17  20.1                   NaN
#
#        PowerDistanceHI  IndividualismHI  MasculinityHI  \
# 0                 80.0             35.0           35.0
# 1                 80.0             35.0           35.0
# 2                 80.0             35.0           35.0
# 3                 80.0             35.0           35.0
# 4                 80.0             35.0           35.0
# ...                ...              ...            ...
# 59435             70.0             20.0           40.0
# 59436             70.0             20.0           40.0
# 59437             70.0             20.0           40.0
# 59438             70.0             20.0           40.0
# 59439             70.0             20.0           40.0
#
#        UncertaintyAvoidanceHI  LongTermOrientationHI  IndulgenceHI  Notes
# 0                        70.0                   26.0          32.0    NaN
# 1                        70.0                   26.0          32.0    NaN
# 2                        70.0                   26.0          32.0    NaN
# 3                        70.0                   26.0          32.0    NaN
# 4                        70.0                   26.0          32.0    NaN
# ...                       ...                    ...           ...    ...
# 59435                    30.0                   57.0          35.0    NaN
# 59436                    30.0                   57.0          35.0    NaN
# 59437                    30.0                   57.0          35.0    NaN
# 59438                    30.0                   57.0          35.0    NaN
# 59439                    30.0                   57.0          35.0    NaN
#
# [59440 rows x 75 columns]

# %%
df = df.rename(columns={"IndividualismHI": "Ind_score"})
#create variable split around 50
df['Ind_ms'] = df['Ind_score'].apply(lambda x: 1 if x < 50 else 2)

#global median split
df_col = df.loc[df['Ind_ms']==1] #dataframe for collectivist countries
df_ind = df.loc[df['Ind_ms']==2] #dataframe for individualist countries
df = df.dropna(subset=['Ind_ms'])
#59440 participants

# %% [markdown]
# # Demographic descriptives

# %%
# Calculate percentage of men and women
#1 is male, 2 is female, 4 is other
gender_counts = df['Gender'].value_counts(normalize=True) * 100
percentage_men = gender_counts.get(1, 0)  
percentage_women = gender_counts.get(2, 0) 
percentage_other = gender_counts.get(4, 0)  # Get percentage of other

# Calculate mean and standard deviation for Age
mean_age = df['Age'].mean()
sd_age = df['Age'].std()

# Printing the results
print(f"Percentage of Men: {percentage_men:.2f}%")
print(f"Percentage of Women: {percentage_women:.2f}%")
print(f"Percentage of Other: {percentage_other:.2f}%")
print(f"Mean Age: {mean_age:.2f}")
print(f"Age Standard Deviation: {sd_age:.2f}")
# Out:
# Percentage of Men: 47.74%
# Percentage of Women: 51.56%
# Percentage of Other: 0.70%
# Mean Age: 39.13
# Age Standard Deviation: 15.76

# %%
unique_countries_count = df['Country'].nunique()

print("Number of unique countries:", unique_countries_count)
# Out:
# Number of unique countries: 63

# %%
#Calculate cronbachs alphas
# List of columns that are part of the BELIEFcc scale
belief_items = ['Belief1', 'Belief2', 'Belief3', 'Belief4'] 

# Function to calculate Cronbach's Alpha
def cronbach_alpha(df, items):
    df_items = df[items]
    item_variances = df_items.var(axis=0, ddof=1)
    total_var = df_items.sum(axis=1).var(ddof=1)
    n_items = len(items)
    return (n_items / (n_items - 1)) * (1 - (item_variances.sum() / total_var))

# Calculate Cronbach's Alpha for BELIEFcc
alpha = cronbach_alpha(df, belief_items)
print(f"Cronbach's Alpha for BELIEFcc: {alpha}")
# Out:
# Cronbach's Alpha for BELIEFcc: 0.9463829584688861

# %%
#Calculate cronbachs alphas
# List of columns that are part of the POLICYcc scale
policy_items = ['Policy1', 'Policy2', 'Policy3', 'Policy4','Policy5', 'Policy6', 'Policy7', 'Policy8', 'Policy9'] 

# Function to calculate Cronbach's Alpha
def cronbach_alpha(df, items):
    df_items = df[items]
    item_variances = df_items.var(axis=0, ddof=1)
    total_var = df_items.sum(axis=1).var(ddof=1)
    n_items = len(items)
    return (n_items / (n_items - 1)) * (1 - (item_variances.sum() / total_var))

# Calculate Cronbach's Alpha for POLICYcc
alpha = cronbach_alpha(df, policy_items)
print(f"Cronbach's Alpha for POLICYcc: {alpha}")
# Out:
# Cronbach's Alpha for POLICYcc: 0.9098078362900452

# %% [markdown]
# ## Main manuscript analyses

# %%
import warnings
warnings.filterwarnings('ignore')

# Load R in Python
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %R library(lme4)
# %R library(lmerTest)
# %R library(ordinal)
# %R library(EMAtools) #for calculating cohens d
# %R library(effectsize) #for calculating ORs
# Out:
# array(['EMAtools', 'openxlsx', 'performance', 'MuMIn', 'effectsize',
#        'ordinal', 'lmerTest', 'lme4', 'Matrix', 'tools', 'stats',
#        'graphics', 'grDevices', 'utils', 'datasets', 'methods', 'base'],
#       dtype='<U11')

# %% [markdown]
# # 1 Do climate beliefs and behaviors differ across the individualism/collectivism spectrum?

# %%
#create control condition dataframe
dfc = df[df['condName'] == "Control"]
dfc['condName'] = dfc['condName'].replace(['Control'], 'aControl')
#5085 rows

# %% [markdown]
# # 1.1 Climate Belief

# %%
dfc_belief = pd.melt(
    dfc.loc[:, ['ResponseId', 'Country', 'condName', 'Ind_score', 'Ind_ms', "Income", "Edu", "Age", "Gender", "GDP", 'ide', 'Ideology', 'Belief1', 'Belief2', 'Belief3', 'Belief4']],
    id_vars=['ResponseId', 'Country', 'condName', 'Ind_score', 'Ind_ms', "Income", "Edu", "Age", "Gender", "GDP", 'ide', 'Ideology'],
    var_name="Item",
    value_name="Belief"
)
#4769 participants

# %%
#deal with missing data for key outcome variable
dfc_belief = dfc_belief.dropna(subset=["Belief"])

# %Rpush dfc_belief

# %%
# %%R
#
# M1 <- lmer(Belief ~ Ind_score + (1 | Country) + (1 | ResponseId) + (1 | Item), data = dfc_belief)
# print(summary(M1))
#
# # Calculate Cohen's d
# cohens_d <- lme.dscore(M1, data = dfc_belief, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Belief ~ Ind_score + (1 | Country) + (1 | ResponseId) + (1 |
#     Item)
#    Data: dfc_belief
#
# REML criterion at convergence: 171620.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.0436 -0.2857  0.0931  0.3180  5.6654
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 517.3986 22.7464
#  Country    (Intercept)  26.6870  5.1659
#  Item       (Intercept)   0.2871  0.5358
#  Residual               159.5155 12.6299
# Number of obs: 20015, groups:  ResponseId, 5011; Country, 62; Item, 4
#
# Fixed effects:
#             Estimate Std. Error       df t value Pr(>|t|)
# (Intercept) 86.57404    1.71580 67.47562  50.457  < 2e-16 ***
# Ind_score   -0.14498    0.03262 56.48924  -4.444 4.17e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#           (Intr)
# Ind_score -0.880
# # R2 for Mixed Models
#
#   Conditional R2: 0.778
#      Marginal R2: 0.019
#                   t       df         d
# Ind_score -4.444262 56.48924 -1.182624

# %%
# %%R
#
# #standardize variables
# dfc_belief$Income <- scale(dfc_belief$Income)
# dfc_belief$Edu <- scale(dfc_belief$Edu)
# dfc_belief$Age <- scale(dfc_belief$Age)
# dfc_belief$ide <- scale(dfc_belief$ide)
# dfc_belief$GDP <- scale(dfc_belief$GDP)
#
# M1 <- lmer(Belief ~ Ind_score + Income + Edu + Age + as.factor(Gender) + ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item), data = dfc_belief)
# print(summary(M1))
#
# cohens_d <- lme.dscore(M1, data = dfc_belief, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Belief ~ Ind_score + Income + Edu + Age + as.factor(Gender) +
#     ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item)
#    Data: dfc_belief
#
# REML criterion at convergence: 127217.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.2866 -0.2872  0.0890  0.3210  5.9492
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 500.0621 22.3621
#  Country    (Intercept)  19.1985  4.3816
#  Item       (Intercept)   0.3102  0.5569
#  Residual               147.5534 12.1472
# Number of obs: 14958, groups:  ResponseId, 3742; Country, 59; Item, 4
#
# Fixed effects:
#                        Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)            82.75428    1.90519   69.96054  43.436  < 2e-16 ***
# Ind_score              -0.11805    0.03197   58.08438  -3.692 0.000493 ***
# Income                  1.00839    0.44410 2422.16213   2.271 0.023257 *
# Edu                     1.07706    0.41220 3708.11569   2.613 0.009012 **
# Age                    -1.10851    0.41499 3507.08488  -2.671 0.007594 **
# as.factor(Gender)2      4.13471    0.78035 3731.33717   5.299 1.24e-07 ***
# as.factor(Gender)4      2.17106    4.46909 3719.03048   0.486 0.627142
# as.factor(Gender)NaN  -13.13498    7.03911 3705.56088  -1.866 0.062120 .
# ide                    -4.33862    0.39349 3674.49921 -11.026  < 2e-16 ***
# GDP                    -1.27625    1.36435   32.06643  -0.935 0.356560
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) Ind_sc Income Edu    Age    a.(G)2 a.(G)4 a.(G)N ide
# Ind_score   -0.861
# Income      -0.005 -0.041
# Edu         -0.046  0.044 -0.260
# Age          0.109 -0.138  0.007 -0.019
# as.fctr(G)2 -0.199 -0.017  0.077 -0.030  0.080
# as.fctr(G)4 -0.036 -0.005  0.007 -0.001  0.046  0.107
# as.fct(G)NN -0.012 -0.012  0.009 -0.013  0.032  0.059  0.010
# ide         -0.077  0.062 -0.058  0.033 -0.056  0.090  0.099 -0.005
# GDP          0.413 -0.236 -0.068 -0.010  0.009 -0.011 -0.001 -0.003 -0.016
#                                t         df           d
# Ind_score             -3.6920804   58.08438 -0.96888327
# Income                 2.2706228 2422.16213  0.09227273
# Edu                    2.6129763 3708.11569  0.08582006
# Age                   -2.6711652 3507.08488 -0.09021061
# as.factor(Gender)2     5.2985117 3731.33717  0.17348089
# as.factor(Gender)4     0.4857942 3719.03048  0.01593190
# as.factor(Gender)NaN  -1.8659992 3705.56088 -0.06130762
# ide                  -11.0260511 3674.49921 -0.36379014
# GDP                   -0.9354274   32.06643 -0.33038080

# %% [markdown]
# # 1.2 Climate Policy Support

# %%
dfc_policy = pd.melt(
    dfc.loc[:, ['ResponseId', 'Country', 'condName', 'Ind_score', 'Ind_ms', "Income", "Edu", "Age", "Gender", "GDP", 'ide', 'Ideology', 'Policy1', 'Policy2', 'Policy3', 'Policy4','Policy5', 'Policy6', 'Policy7', 'Policy8', 'Policy9']],
    id_vars=['ResponseId', 'Country', 'condName', 'Ind_score', 'Ind_ms', "Income", "Edu", "Age", "Gender", "GDP", 'ide', 'Ideology'],
    var_name="Item",
    value_name="Policy"
)

#deal with missing data
dfc_policy = dfc_policy.dropna(subset=["Policy"])

# %Rpush dfc_policy

# %%
# %%R
#
# M1 <- lmer(Policy ~ Ind_score + (1 | Country) + (1 | ResponseId) + (1 | Item), data = dfc_policy)
# print(summary(M1))
#
# cohens_d <- lme.dscore(M1, data = dfc_policy, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Policy ~ Ind_score + (1 | Country) + (1 | ResponseId) + (1 |
#     Item)
#    Data: dfc_policy
#
# REML criterion at convergence: 396770.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.5698 -0.5259  0.0684  0.6332  4.0948
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 309.73   17.599
#  Country    (Intercept)  14.99    3.872
#  Item       (Intercept) 150.29   12.259
#  Residual               434.17   20.837
# Number of obs: 43407, groups:  ResponseId, 4980; Country, 62; Item, 9
#
# Fixed effects:
#             Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)  74.8101     4.2879  9.6758  17.447 1.24e-08 ***
# Ind_score    -0.1024     0.0249 60.0474  -4.112 0.000121 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#           (Intr)
# Ind_score -0.270
#                   t       df         d
# Ind_score -4.112419 60.04738 -1.061403

# %%
# %%R
# #standardize variables
# dfc_policy$Income <- scale(dfc_policy$Income)
# dfc_policy$Edu <- scale(dfc_policy$Edu)
# dfc_policy$Age <- scale(dfc_policy$Age)
# dfc_policy$ide <- scale(dfc_policy$ide)
# dfc_policy$GDP <- scale(dfc_policy$GDP)
#
# M1 <- lmer(Policy ~ Ind_score + Income + Edu + Age + as.factor(Gender) + ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item), data = dfc_policy)
# print(summary(M1))
#
# cohens_d <- lme.dscore(M1, data = dfc_policy, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Policy ~ Ind_score + Income + Edu + Age + as.factor(Gender) +
#     ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item)
#    Data: dfc_policy
#
# REML criterion at convergence: 298417
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6011 -0.5260  0.0624  0.6276  4.2189
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 314.39   17.731
#  Country    (Intercept)  13.46    3.669
#  Item       (Intercept) 146.43   12.101
#  Residual               406.88   20.171
# Number of obs: 32856, groups:  ResponseId, 3735; Country, 59; Item, 9
#
# Fixed effects:
#                       Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)            73.6862     4.3272   10.5520  17.029 5.16e-09 ***
# Ind_score              -0.0963     0.0266   58.5572  -3.621 0.000615 ***
# Income                  0.4472     0.3647 2454.5378   1.226 0.220248
# Edu                     1.5086     0.3377 3695.2546   4.467 8.17e-06 ***
# Age                    -0.1036     0.3412 3507.5279  -0.304 0.761392
# as.factor(Gender)2      1.8237     0.6409 3709.4652   2.846 0.004457 **
# as.factor(Gender)4      5.9736     3.6612 3682.4961   1.632 0.102848
# as.factor(Gender)NaN   -8.6280     5.5370 3705.1725  -1.558 0.119258
# ide                    -2.5535     0.3232 3658.8377  -7.900 3.67e-15 ***
# GDP                    -0.5949     1.1394   32.8059  -0.522 0.605060
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) Ind_sc Income Edu    Age    a.(G)2 a.(G)4 a.(G)N ide
# Ind_score   -0.315
# Income       0.000 -0.042
# Edu         -0.017  0.045 -0.260
# Age          0.040 -0.137  0.009 -0.022
# as.fctr(G)2 -0.072 -0.017  0.077 -0.030  0.082
# as.fctr(G)4 -0.013 -0.004  0.007 -0.001  0.046  0.107
# as.fct(G)NN -0.005 -0.011  0.012 -0.020  0.023  0.061  0.011
# ide         -0.028  0.062 -0.059  0.034 -0.055  0.089  0.099 -0.004
# GDP          0.152 -0.234 -0.068 -0.010  0.009 -0.011 -0.001 -0.005 -0.015
#                               t         df           d
# Ind_score            -3.6205014   58.55719 -0.94625588
# Income                1.2261813 2454.53781  0.04949939
# Edu                   4.4669063 3695.25465  0.14696525
# Age                  -0.3036768 3507.52789 -0.01025513
# as.factor(Gender)2    2.8456138 3709.46521  0.09344376
# as.factor(Gender)4    1.6316080 3682.49615  0.05377429
# as.factor(Gender)NaN -1.5582568 3705.17249 -0.05119939
# ide                  -7.8997307 3658.83770 -0.26119852
# GDP                  -0.5221698   32.80594 -0.18233311

# %% [markdown]
# # 1.3 Sharing

# %%
#deal with missing data
dfc_share = dfc.dropna(subset=["SHAREcc"])

# %Rpush dfc_share

# %%
# %%R
#
# M1 <- glmer(SHAREcc ~ Ind_score + (1 | Country), family = binomial, data = dfc_share)
# print(summary(M1))
#
# cohens_d <- lme.dscore(M1, data = dfc_share, type = "lme4")
# print(cohens_d)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: SHAREcc ~ Ind_score + (1 | Country)
#    Data: dfc_share
#
#      AIC      BIC   logLik deviance df.resid
#   4776.0   4794.8  -2385.0   4770.0     3884
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.5748 -0.7507 -0.3678  0.8169  3.1562
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  Country (Intercept) 1.098    1.048
# Number of obs: 3887, groups:  Country, 62
#
# Fixed effects:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)  0.949605   0.306569   3.098 0.001951 **
# Ind_score   -0.020534   0.006038  -3.401 0.000672 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#           (Intr)
# Ind_score -0.888
#                   t       df          d
# Ind_score -3.448755 58.17713 -0.9043077

# %%
# %%R
#
# #standardize variables
# dfc_share$Income <- scale(dfc_share$Income)
# dfc_share$Edu <- scale(dfc_share$Edu)
# dfc_share$Age <- scale(dfc_share$Age)
# dfc_share$ide <- scale(dfc_share$ide)
# dfc_share$GDP <- scale(dfc_share$GDP)
#
# M1 <- glmer(SHAREcc ~ Ind_score + Income + Edu + Age + as.factor(Gender) + ide + GDP + (1 | Country), family = binomial, data = dfc_share)
# print(summary(M1))
#
# cohens_d <- lme.dscore(M1, data = dfc_share, type = "lme4")
# print(cohens_d)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: SHAREcc ~ Ind_score + Income + Edu + Age + as.factor(Gender) +
#     ide + GDP + (1 | Country)
#    Data: dfc_share
#
#      AIC      BIC   logLik deviance df.resid
#   3643.2   3709.1  -1810.6   3621.2     2938
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1861 -0.8032  0.3732  0.7730  3.9535
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  Country (Intercept) 0.8491   0.9215
# Number of obs: 2949, groups:  Country, 59
#
# Fixed effects:
#                       Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.095059   0.330389   3.314 0.000918 ***
# Ind_score            -0.016430   0.005721  -2.872 0.004082 **
# Income               -0.024296   0.050393  -0.482 0.629720
# Edu                   0.128278   0.044511   2.882 0.003952 **
# Age                  -0.254928   0.045049  -5.659 1.52e-08 ***
# as.factor(Gender)2   -0.287570   0.084282  -3.412 0.000645 ***
# as.factor(Gender)4   -0.232959   0.460842  -0.506 0.613203
# as.factor(Gender)NaN -0.454250   0.623620  -0.728 0.466363
# ide                   0.184598   0.042350   4.359 1.31e-05 ***
# GDP                   0.274419   0.271444   1.011 0.312035
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) Ind_sc Income Edu    Age    a.(G)2 a.(G)4 a.(G)N ide
# Ind_score   -0.866
# Income      -0.005 -0.029
# Edu         -0.027  0.027 -0.281
# Age          0.051 -0.064 -0.003 -0.022
# as.fctr(G)2 -0.134 -0.002  0.090 -0.022  0.066
# as.fctr(G)4 -0.030  0.004  0.016 -0.006  0.046  0.113
# as.fct(G)NN -0.011 -0.006  0.018 -0.027  0.024  0.074  0.014
# ide         -0.026  0.022 -0.063  0.026 -0.081  0.064  0.099 -0.008
# GDP          0.456 -0.219 -0.044 -0.002  0.001 -0.009 -0.002 -0.003 -0.002
#                               t         df           d
# Ind_score            -2.8600971   53.09722 -0.78500946
# Income               -0.4008893 2871.45631 -0.01496247
# Edu                   2.8965597 2923.55765  0.10714124
# Age                  -5.7967142 2938.24576 -0.21387884
# as.factor(Gender)2   -3.4398763 2916.06192 -0.12740147
# as.factor(Gender)4   -0.5260725 2905.32033 -0.01951994
# as.factor(Gender)NaN -0.7147803 2894.76774 -0.02657025
# ide                   4.4226069 2933.05888  0.16332322
# GDP                   1.0595793   43.38645  0.32172618

# %% [markdown]
# # 1.4 Behavior

# %%
# deal with missing data
dfc_WEPT = dfc.dropna(subset=["WEPTcc"])

# %Rpush dfc_WEPT

# %%
# %%R
#
# M1 <- clmm(as.factor(WEPTcc) ~ Ind_score + (1 | Country), data = dfc_WEPT, threshold = "equidistant",  doFit = TRUE)
# print(summary(M1))
#
# # Extract fixed effects coefficients directly
# model_coef <- coef(M1)
#
# # Calculate odds ratios for fixed effects
# odds_ratios <- exp(model_coef)
# Out:
# Cumulative Link Mixed Model fitted with the Laplace approximation
#
# formula: as.factor(WEPTcc) ~ Ind_score + (1 | Country)
# data:    dfc_WEPT
#
#  link  threshold   nobs logLik   AIC      niter    max.grad cond.H
#  logit equidistant 5062 -8095.22 16198.44 168(513) 1.40e-02 1.3e+04
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  Country (Intercept) 0.1882   0.4338
# Number of groups:  Country 62
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# Ind_score -0.0009241  0.0026980  -0.343    0.732
#
# Threshold coefficients:
#              Estimate Std. Error z value
# threshold.1 -1.377488   0.141173  -9.757
# spacing      0.187772   0.004336  43.307
# (23 observations deleted due to missingness)

# %%
# %%R
#
# #convert odds ratio to d score
# oddsratio_to_d(odds_ratios)
# Out:
#   threshold.1       spacing     Ind_score
# -0.7594489766  0.1035240677 -0.0005094889

# %% [markdown]
# # 2. How do climate interventions impact the conceptual and behavioral outcomes of people in countries along the individualism spectrum?

# %% [markdown]
# ## 2.1 Interventions’ Impact on Beliefs

# %%
df_belief = pd.melt(
    df.loc[:, ['ResponseId', 'Country', 'condName', 'Ind_score', "Ind_ms", "Income", "Edu", "Age", "Gender", "GDP", "ide", 'Belief1', 'Belief2', 'Belief3', 'Belief4']],
    id_vars=['ResponseId', 'Country', 'condName', 'Ind_score', "Ind_ms", "Income", "Edu", "Age", "Gender", "GDP", "ide"],
    var_name="Item",
    value_name="Belief"
)
df_belief['condName'] = df_belief['condName'].replace(['Control'], 'aControl')

# %%
#deal with missing data
df_belief = df_belief.dropna(subset=["Belief"])
# %Rpush df_belief

# %%
# %%R
# M1 <- lmer(Belief ~ condName*Ind_score + (1 | Country) + (1 | ResponseId) + (1 | Item), data = df_belief)
# print(summary(M1))
#
# rsq <- r2(M1) #marginal and conditional R² values
# print(rsq)
#
# # Calculate Cohen's d
# cohens_d <- lme.dscore(M1, data = df_belief, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Belief ~ condName * Ind_score + (1 | Country) + (1 | ResponseId) +
#     (1 | Item)
#    Data: df_belief
#
# REML criterion at convergence: 1982366
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.2906 -0.2693  0.0885  0.2938  6.0000
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 502.0822 22.4072
#  Country    (Intercept)  26.6574  5.1631
#  Item       (Intercept)   0.2813  0.5303
#  Residual               147.4639 12.1435
# Number of obs: 233116, groups:  ResponseId, 58370; Country, 62; Item, 4
#
# Fixed effects:
#                                      Estimate Std. Error         df t value
# (Intercept)                         8.725e+01  1.643e+00  1.022e+02  53.106
# condNameBindingMoral               -5.184e-01  1.122e+00  5.825e+04  -0.462
# condNameCollectAction               6.224e-01  1.118e+00  5.824e+04   0.557
# condNameDynamicNorm                -4.526e-02  1.119e+00  5.828e+04  -0.040
# condNameFutureSelfCont              1.961e+00  1.173e+00  5.827e+04   1.671
# condNameLetterFutureGen             9.948e-01  1.182e+00  5.825e+04   0.842
# condNameNegativeEmotions           -1.023e+00  1.121e+00  5.826e+04  -0.913
# condNamePluralIgnorance            -4.946e-01  1.130e+00  5.823e+04  -0.438
# condNamePsychDistance               3.605e-01  1.147e+00  5.825e+04   0.314
# condNameSciConsens                  3.562e-01  1.108e+00  5.825e+04   0.321
# condNameSystemJust                  6.705e-01  1.120e+00  5.825e+04   0.599
# condNameWorkTogetherNorm            1.513e-01  1.117e+00  5.823e+04   0.135
# Ind_score                          -1.616e-01  3.114e-02  8.346e+01  -5.188
# condNameBindingMoral:Ind_score      2.909e-02  1.817e-02  5.824e+04   1.601
# condNameCollectAction:Ind_score     3.030e-02  1.814e-02  5.823e+04   1.670
# condNameDynamicNorm:Ind_score       1.427e-02  1.814e-02  5.826e+04   0.787
# condNameFutureSelfCont:Ind_score   -2.459e-03  1.907e-02  5.825e+04  -0.129
# condNameLetterFutureGen:Ind_score   1.544e-02  1.937e-02  5.824e+04   0.797
# condNameNegativeEmotions:Ind_score  3.189e-02  1.818e-02  5.825e+04   1.754
# condNamePluralIgnorance:Ind_score   2.495e-02  1.825e-02  5.823e+04   1.367
# condNamePsychDistance:Ind_score     5.098e-02  1.844e-02  5.823e+04   2.764
# condNameSciConsens:Ind_score        1.651e-02  1.802e-02  5.824e+04   0.916
# condNameSystemJust:Ind_score        2.110e-02  1.816e-02  5.824e+04   1.162
# condNameWorkTogetherNorm:Ind_score -1.275e-02  1.813e-02  5.823e+04  -0.703
#                                    Pr(>|t|)
# (Intercept)                         < 2e-16 ***
# condNameBindingMoral                 0.6441
# condNameCollectAction                0.5777
# condNameDynamicNorm                  0.9677
# condNameFutureSelfCont               0.0947 .
# condNameLetterFutureGen              0.4000
# condNameNegativeEmotions             0.3614
# condNamePluralIgnorance              0.6615
# condNamePsychDistance                0.7533
# condNameSciConsens                   0.7479
# condNameSystemJust                   0.5493
# condNameWorkTogetherNorm             0.8922
# Ind_score                          1.46e-06 ***
# condNameBindingMoral:Ind_score       0.1094
# condNameCollectAction:Ind_score      0.0949 .
# condNameDynamicNorm:Ind_score        0.4315
# condNameFutureSelfCont:Ind_score     0.8974
# condNameLetterFutureGen:Ind_score    0.4254
# condNameNegativeEmotions:Ind_score   0.0794 .
# condNamePluralIgnorance:Ind_score    0.1716
# condNamePsychDistance:Ind_score      0.0057 **
# condNameSciConsens:Ind_score         0.3596
# condNameSystemJust:Ind_score         0.2453
# condNameWorkTogetherNorm:Ind_score   0.4821
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                                              t          df             d
# condNameBindingMoral               -0.46203251 58253.21273 -0.0038286229
# condNameCollectAction               0.55680805 58237.09911  0.0046146167
# condNameDynamicNorm                -0.04043566 58276.73035 -0.0003350016
# condNameFutureSelfCont              1.67099908 58267.90735  0.0138449533
# condNameLetterFutureGen             0.84159835 58251.56461  0.0069739860
# condNameNegativeEmotions           -0.91272420 58255.10278 -0.0075631475
# condNamePluralIgnorance            -0.43784559 58232.44072 -0.0036288455
# condNamePsychDistance               0.31431751 58245.13660  0.0026047661
# condNameSciConsens                  0.32141158 58246.45916  0.0026635248
# condNameSystemJust                  0.59885074 58245.76118  0.0049626817
# condNameWorkTogetherNorm            0.13547857 58234.24163  0.0011228232
# Ind_score                          -5.18822844    83.45517 -1.1358538844
# condNameBindingMoral:Ind_score      1.60086142 58243.62840  0.0132665966
# condNameCollectAction:Ind_score     1.66998382 58227.43496  0.0138413493
# condNameDynamicNorm:Ind_score       0.78655037 58261.33155  0.0065172793
# condNameFutureSelfCont:Ind_score   -0.12896223 58252.72752 -0.0010686473
# condNameLetterFutureGen:Ind_score   0.79709345 58238.69223  0.0066059218
# condNameNegativeEmotions:Ind_score  1.75426260 58246.07203  0.0145375519
# condNamePluralIgnorance:Ind_score   1.36713623 58226.69589  0.0113313255
# condNamePsychDistance:Ind_score     2.76447167 58232.74993  0.0229117620
# condNameSciConsens:Ind_score        0.91613057 58239.51137  0.0075923900
# condNameSystemJust:Ind_score        1.16180701 58240.27328  0.0096283592
# condNameWorkTogetherNorm:Ind_score -0.70301243 58227.51854 -0.0058267832
# Correlation matrix not shown by default, as p = 24 > 12.
# Use print(summary(M1), correlation=TRUE)  or
#     vcov(summary(M1))        if you need it

# %%
# %%R
#
# #standardize variables
# df_belief$Income <- scale(df_belief$Income)
# df_belief$Edu <- scale(df_belief$Edu)
# df_belief$Age <- scale(df_belief$Age)
# df_belief$ide <- scale(df_belief$ide)
# df_belief$GDP <- scale(df_belief$GDP)
#
# M1 <- lmer(Belief ~ condName*Ind_score + Income + Edu + Age + as.factor(Gender) + ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item), data = df_belief)
# print(summary(M1))
#
# rsq <- r2(M1) #marginal and conditional R² values
# print(rsq)
#
# # Calculate Cohen's d
# cohens_d <- lme.dscore(M1, data = df_belief, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# Belief ~ condName * Ind_score + Income + Edu + Age + as.factor(Gender) +
#     ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item)
#    Data: df_belief
#
# REML criterion at convergence: 1509872
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.5396 -0.2774  0.0835  0.3020  6.2440
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 478.7673 21.8808
#  Country    (Intercept)  20.2067  4.4952
#  Item       (Intercept)   0.3876  0.6226
#  Residual               137.8344 11.7403
# Number of obs: 178878, groups:  ResponseId, 44755; Country, 59; Item, 4
#
# Fixed effects:
#                                      Estimate Std. Error         df t value
# (Intercept)                         8.471e+01  1.779e+00  1.052e+02  47.615
# condNameBindingMoral                3.700e-01  1.303e+00  4.466e+04   0.284
# condNameCollectAction               6.234e-01  1.305e+00  4.467e+04   0.478
# condNameDynamicNorm                 3.218e-01  1.303e+00  4.467e+04   0.247
# condNameFutureSelfCont              2.476e+00  1.375e+00  4.467e+04   1.800
# condNameLetterFutureGen             1.572e+00  1.382e+00  4.468e+04   1.138
# condNameNegativeEmotions           -6.118e-01  1.310e+00  4.466e+04  -0.467
# condNamePluralIgnorance            -6.144e-01  1.304e+00  4.465e+04  -0.471
# condNamePsychDistance               1.338e+00  1.347e+00  4.467e+04   0.993
# condNameSciConsens                  6.604e-01  1.295e+00  4.466e+04   0.510
# condNameSystemJust                  5.515e-01  1.309e+00  4.465e+04   0.421
# condNameWorkTogetherNorm            3.581e-01  1.306e+00  4.465e+04   0.274
# Ind_score                          -1.594e-01  2.974e-02  9.278e+01  -5.359
# Income                              8.935e-01  1.285e-01  4.027e+04   6.954
# Edu                                 4.698e-01  1.165e-01  4.451e+04   4.031
# Age                                -9.301e-01  1.206e-01  4.357e+04  -7.711
# as.factor(Gender)2                  4.690e+00  2.202e-01  4.471e+04  21.298
# as.factor(Gender)4                  6.800e+00  1.381e+00  4.466e+04   4.925
# as.factor(Gender)NaN               -6.847e+00  2.048e+00  4.480e+04  -3.344
# ide                                -4.452e+00  1.114e-01  4.455e+04 -39.964
# GDP                                -4.211e-01  1.318e+00  5.181e+01  -0.320
# condNameBindingMoral:Ind_score      1.701e-02  2.051e-02  4.466e+04   0.830
# condNameCollectAction:Ind_score     3.466e-02  2.054e-02  4.466e+04   1.687
# condNameDynamicNorm:Ind_score       6.363e-03  2.049e-02  4.467e+04   0.311
# condNameFutureSelfCont:Ind_score   -7.994e-03  2.164e-02  4.466e+04  -0.369
# condNameLetterFutureGen:Ind_score   8.995e-03  2.187e-02  4.467e+04   0.411
# condNameNegativeEmotions:Ind_score  1.961e-02  2.058e-02  4.465e+04   0.953
# condNamePluralIgnorance:Ind_score   2.479e-02  2.049e-02  4.465e+04   1.210
# condNamePsychDistance:Ind_score     3.187e-02  2.096e-02  4.466e+04   1.520
# condNameSciConsens:Ind_score        1.178e-02  2.041e-02  4.466e+04   0.577
# condNameSystemJust:Ind_score        2.263e-02  2.056e-02  4.465e+04   1.101
# condNameWorkTogetherNorm:Ind_score -9.959e-03  2.057e-02  4.465e+04  -0.484
#                                    Pr(>|t|)
# (Intercept)                         < 2e-16 ***
# condNameBindingMoral               0.776505
# condNameCollectAction              0.632789
# condNameDynamicNorm                0.804863
# condNameFutureSelfCont             0.071793 .
# condNameLetterFutureGen            0.255139
# condNameNegativeEmotions           0.640603
# condNamePluralIgnorance            0.637451
# condNamePsychDistance              0.320665
# condNameSciConsens                 0.610009
# condNameSystemJust                 0.673488
# condNameWorkTogetherNorm           0.783902
# Ind_score                          6.06e-07 ***
# Income                             3.60e-12 ***
# Edu                                5.56e-05 ***
# Age                                1.28e-14 ***
# as.factor(Gender)2                  < 2e-16 ***
# as.factor(Gender)4                 8.46e-07 ***
# as.factor(Gender)NaN               0.000827 ***
# ide                                 < 2e-16 ***
# GDP                                0.750567
# condNameBindingMoral:Ind_score     0.406760
# condNameCollectAction:Ind_score    0.091521 .
# condNameDynamicNorm:Ind_score      0.756118
# condNameFutureSelfCont:Ind_score   0.711791
# condNameLetterFutureGen:Ind_score  0.680903
# condNameNegativeEmotions:Ind_score 0.340692
# condNamePluralIgnorance:Ind_score  0.226421
# condNamePsychDistance:Ind_score    0.128428
# condNameSciConsens:Ind_score       0.563718
# condNameSystemJust:Ind_score       0.270983
# condNameWorkTogetherNorm:Ind_score 0.628224
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# optimizer (nloptwrap) convergence code: 0 (OK)
# Model failed to converge with max|grad| = 0.361002 (tol = 0.002, component 1)
#
# # R2 for Mixed Models
#
#   Conditional R2: 0.798
#      Marginal R2: 0.066
# Correlation matrix not shown by default, as p = 32 > 12.
# Use print(summary(M1), correlation=TRUE)  or
#     vcov(summary(M1))        if you need it
#
# In addition: Warning message:
# In checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv,  :
#   Model failed to converge with max|grad| = 0.361002 (tol = 0.002, component 1)

# %% [markdown]
# ## 2.2 Interventions’ Impact on Policy Support.

# %%
df_policy = pd.melt(
    df.loc[:, ['ResponseId', 'Country', 'condName', 'Ind_score', "Ind_ms", 'Income', 'Edu', 'Age', 'Gender', "GDP", "ide",'Policy1', 'Policy2', 'Policy3', 'Policy4','Policy5', 'Policy6', 'Policy7', 'Policy8', 'Policy9']],
    id_vars=['ResponseId', 'Country', 'condName', 'Ind_score', "Ind_ms", 'Income', 'Edu', 'Age', 'Gender', "GDP", "ide"],
    var_name="Item",
    value_name="Policy"
)
df_policy['condName'] = df_policy['condName'].replace(['Control'], 'aControl')

#deal with missing data
df_policy = df_policy.dropna(subset=["Policy"])

# %Rpush df_policy

# %%
# %%R
#
# M1 <- lmer(Policy ~ condName*Ind_score + (1 | Country) + (1 | ResponseId) + (1 | Item), data = df_policy)
# print(summary(M1))
#
# #rsq <- r2(M1) #marginal and conditional R² values
# #print(rsq)
#
# # Calculate Cohen's d
# cohens_d <- lme.dscore(M1, data = df_policy, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Policy ~ condName * Ind_score + (1 | Country) + (1 | ResponseId) +
#     (1 | Item)
#    Data: df_policy
#
# REML criterion at convergence: 4615950
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.7684 -0.5203  0.0709  0.6338  4.6549
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 307.22   17.528
#  Country    (Intercept)  17.79    4.218
#  Item       (Intercept) 140.49   11.853
#  Residual               429.63   20.728
# Number of obs: 505706, groups:  ResponseId, 57970; Country, 62; Item, 9
#
# Fixed effects:
#                                      Estimate Std. Error         df t value
# (Intercept)                         7.569e+01  4.167e+00  9.854e+00  18.164
# condNameBindingMoral                5.684e-01  9.172e-01  5.787e+04   0.620
# condNameCollectAction               2.196e+00  9.131e-01  5.783e+04   2.405
# condNameDynamicNorm                 1.191e+00  9.150e-01  5.790e+04   1.301
# condNameFutureSelfCont              1.938e+00  9.592e-01  5.790e+04   2.020
# condNameLetterFutureGen             1.661e+00  9.672e-01  5.784e+04   1.717
# condNameNegativeEmotions           -1.797e+00  9.167e-01  5.787e+04  -1.961
# condNamePluralIgnorance            -5.386e-01  9.224e-01  5.785e+04  -0.584
# condNamePsychDistance              -1.029e+00  9.383e-01  5.798e+04  -1.097
# condNameSciConsens                  3.256e-01  9.062e-01  5.790e+04   0.359
# condNameSystemJust                  7.511e-01  9.147e-01  5.782e+04   0.821
# condNameWorkTogetherNorm            1.003e+00  9.120e-01  5.787e+04   1.100
# Ind_score                          -1.233e-01  2.544e-02  8.488e+01  -4.847
# condNameBindingMoral:Ind_score      2.614e-03  1.485e-02  5.775e+04   0.176
# condNameCollectAction:Ind_score     1.305e-02  1.483e-02  5.772e+04   0.880
# condNameDynamicNorm:Ind_score      -7.677e-04  1.483e-02  5.777e+04  -0.052
# condNameFutureSelfCont:Ind_score    1.940e-03  1.559e-02  5.778e+04   0.124
# condNameLetterFutureGen:Ind_score   2.007e-02  1.583e-02  5.771e+04   1.267
# condNameNegativeEmotions:Ind_score  2.668e-02  1.486e-02  5.772e+04   1.795
# condNamePluralIgnorance:Ind_score   1.549e-02  1.490e-02  5.771e+04   1.039
# condNamePsychDistance:Ind_score     4.236e-02  1.508e-02  5.784e+04   2.808
# condNameSciConsens:Ind_score        7.756e-03  1.473e-02  5.778e+04   0.526
# condNameSystemJust:Ind_score        4.285e-03  1.484e-02  5.770e+04   0.289
# condNameWorkTogetherNorm:Ind_score -1.966e-02  1.482e-02  5.776e+04  -1.327
#                                    Pr(>|t|)
# (Intercept)                        6.67e-09 ***
# condNameBindingMoral                0.53546
# condNameCollectAction               0.01616 *
# condNameDynamicNorm                 0.19309
# condNameFutureSelfCont              0.04339 *
# condNameLetterFutureGen             0.08593 .
# condNameNegativeEmotions            0.04991 *
# condNamePluralIgnorance             0.55930
# condNamePsychDistance               0.27274
# condNameSciConsens                  0.71939
# condNameSystemJust                  0.41157
# condNameWorkTogetherNorm            0.27141
# Ind_score                          5.60e-06 ***
# condNameBindingMoral:Ind_score      0.86030
# condNameCollectAction:Ind_score     0.37878
# condNameDynamicNorm:Ind_score       0.95871
# condNameFutureSelfCont:Ind_score    0.90094
# condNameLetterFutureGen:Ind_score   0.20502
# condNameNegativeEmotions:Ind_score  0.07258 .
# condNamePluralIgnorance:Ind_score   0.29859
# condNamePsychDistance:Ind_score     0.00498 **
# condNameSciConsens:Ind_score        0.59858
# condNameSystemJust:Ind_score        0.77278
# condNameWorkTogetherNorm:Ind_score  0.18460
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                                              t         df             d
# condNameBindingMoral                0.61970055 57865.2258  0.0051523227
# condNameCollectAction               2.40524480 57828.1178  0.0200041338
# condNameDynamicNorm                 1.30149630 57896.7242  0.0108179741
# condNameFutureSelfCont              2.02000803 57896.0003  0.0167903137
# condNameLetterFutureGen             1.71731939 57836.4573  0.0142817105
# condNameNegativeEmotions           -1.96077513 57868.3179 -0.0163018674
# condNamePluralIgnorance            -0.58388099 57845.4166 -0.0048553423
# condNamePsychDistance              -1.09679090 57975.5203 -0.0091102754
# condNameSciConsens                  0.35927469 57896.9994  0.0029862667
# condNameSystemJust                  0.82114600 57816.3792  0.0068300665
# condNameWorkTogetherNorm            1.09982077 57865.7742  0.0091441013
# Ind_score                          -4.84678230    84.8836 -1.0521353475
# condNameBindingMoral:Ind_score      0.17599784 57748.8191  0.0014647576
# condNameCollectAction:Ind_score     0.88015699 57720.3878  0.0073269886
# condNameDynamicNorm:Ind_score      -0.05176893 57767.1044 -0.0004307833
# condNameFutureSelfCont:Ind_score    0.12447084 57775.3015  0.0010356822
# condNameLetterFutureGen:Ind_score   1.26739869 57708.9084  0.0105516850
# condNameNegativeEmotions:Ind_score  1.79548826 57719.6954  0.0149468801
# condNamePluralIgnorance:Ind_score   1.03947960 57713.3875  0.0086538165
# condNamePsychDistance:Ind_score     2.80815968 57841.5414  0.0233524185
# condNameSciConsens:Ind_score        0.52645246 57779.8661  0.0043802700
# condNameSystemJust:Ind_score        0.28873824 57700.9771  0.0024040456
# condNameWorkTogetherNorm:Ind_score -1.32675134 57757.4436 -0.0110411815
# Correlation matrix not shown by default, as p = 24 > 12.
# Use print(summary(M1), correlation=TRUE)  or
#     vcov(summary(M1))        if you need it

# %%
# %%R
#
# #standardize variables
# df_policy$Income <- scale(df_policy$Income)
# df_policy$Edu <- scale(df_policy$Edu)
# df_policy$Age <- scale(df_policy$Age)
# df_policy$ide <- scale(df_policy$ide)
# df_policy$GDP <- scale(df_policy$GDP)
#
# M1 <- lmer(Policy ~ condName*Ind_score + Income + Edu + Age + as.factor(Gender) + ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item), data = df_policy)
# print(summary(M1))
#
# rsq <- r2(M1) #marginal and conditional R² values
# print(rsq)
#
# # Calculate Cohen's d
# cohens_d <- lme.dscore(M1, data = df_policy, type = "lme4")
# print(cohens_d)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# Policy ~ condName * Ind_score + Income + Edu + Age + as.factor(Gender) +
#     ide + GDP + (1 | Country) + (1 | ResponseId) + (1 | Item)
#    Data: df_policy
#
# REML criterion at convergence: 3556360
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.9194 -0.5235  0.0634  0.6307  4.8265
#
# Random effects:
#  Groups     Name        Variance Std.Dev.
#  ResponseId (Intercept) 303.20   17.413
#  Country    (Intercept)  17.52    4.186
#  Item       (Intercept) 139.38   11.806
#  Residual               403.38   20.084
# Number of obs: 392147, groups:  ResponseId, 44605; Country, 59; Item, 9
#
# Fixed effects:
#                                      Estimate Std. Error         df t value
# (Intercept)                         7.570e+01  4.240e+00  1.078e+01  17.853
# condNameBindingMoral                6.256e-01  1.078e+00  4.452e+04   0.580
# condNameCollectAction               2.706e+00  1.078e+00  4.450e+04   2.509
# condNameDynamicNorm                 3.976e-01  1.077e+00  4.455e+04   0.369
# condNameFutureSelfCont              2.055e+00  1.138e+00  4.453e+04   1.806
# condNameLetterFutureGen             1.839e+00  1.143e+00  4.450e+04   1.608
# condNameNegativeEmotions           -1.777e+00  1.084e+00  4.451e+04  -1.639
# condNamePluralIgnorance            -6.538e-01  1.078e+00  4.451e+04  -0.607
# condNamePsychDistance              -1.238e-01  1.115e+00  4.458e+04  -0.111
# condNameSciConsens                  4.264e-01  1.071e+00  4.454e+04   0.398
# condNameSystemJust                  4.477e-01  1.082e+00  4.450e+04   0.414
# condNameWorkTogetherNorm            1.219e+00  1.079e+00  4.452e+04   1.129
# Ind_score                          -1.368e-01  2.690e-02  8.586e+01  -5.084
# Income                              8.477e-01  1.062e-01  4.181e+04   7.985
# Edu                                 9.494e-01  9.609e-02  4.443e+04   9.881
# Age                                 4.479e-01  9.980e-02  4.384e+04   4.487
# as.factor(Gender)2                  2.026e+00  1.821e-01  4.447e+04  11.128
# as.factor(Gender)4                  6.704e+00  1.143e+00  4.433e+04   5.864
# as.factor(Gender)NaN               -3.633e+00  1.689e+00  4.445e+04  -2.152
# ide                                -2.982e+00  9.215e-02  4.443e+04 -32.359
# GDP                                 6.936e-03  1.226e+00  5.340e+01   0.006
# condNameBindingMoral:Ind_score      3.899e-03  1.696e-02  4.444e+04   0.230
# condNameCollectAction:Ind_score     1.069e-02  1.697e-02  4.442e+04   0.630
# condNameDynamicNorm:Ind_score       9.910e-03  1.694e-02  4.447e+04   0.585
# condNameFutureSelfCont:Ind_score   -1.742e-03  1.789e-02  4.446e+04  -0.097
# condNameLetterFutureGen:Ind_score   1.967e-02  1.809e-02  4.442e+04   1.088
# condNameNegativeEmotions:Ind_score  2.380e-02  1.701e-02  4.442e+04   1.400
# condNamePluralIgnorance:Ind_score   1.878e-02  1.693e-02  4.443e+04   1.109
# condNamePsychDistance:Ind_score     2.891e-02  1.734e-02  4.451e+04   1.667
# condNameSciConsens:Ind_score        6.501e-03  1.688e-02  4.447e+04   0.385
# condNameSystemJust:Ind_score        1.058e-02  1.700e-02  4.444e+04   0.622
# condNameWorkTogetherNorm:Ind_score -2.094e-02  1.700e-02  4.445e+04  -1.232
#                                    Pr(>|t|)
# (Intercept)                        2.37e-09 ***
# condNameBindingMoral                 0.5618
# condNameCollectAction                0.0121 *
# condNameDynamicNorm                  0.7121
# condNameFutureSelfCont               0.0709 .
# condNameLetterFutureGen              0.1078
# condNameNegativeEmotions             0.1012
# condNamePluralIgnorance              0.5440
# condNamePsychDistance                0.9116
# condNameSciConsens                   0.6906
# condNameSystemJust                   0.6792
# condNameWorkTogetherNorm             0.2588
# Ind_score                          2.14e-06 ***
# Income                             1.44e-15 ***
# Edu                                 < 2e-16 ***
# Age                                7.23e-06 ***
# as.factor(Gender)2                  < 2e-16 ***
# as.factor(Gender)4                 4.54e-09 ***
# as.factor(Gender)NaN                 0.0314 *
# ide                                 < 2e-16 ***
# GDP                                  0.9955
# condNameBindingMoral:Ind_score       0.8182
# condNameCollectAction:Ind_score      0.5289
# condNameDynamicNorm:Ind_score        0.5585
# condNameFutureSelfCont:Ind_score     0.9224
# condNameLetterFutureGen:Ind_score    0.2767
# condNameNegativeEmotions:Ind_score   0.1616
# condNamePluralIgnorance:Ind_score    0.2674
# condNamePsychDistance:Ind_score      0.0955 .
# condNameSciConsens:Ind_score         0.7001
# condNameSystemJust:Ind_score         0.5338
# condNameWorkTogetherNorm:Ind_score   0.2181
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# # R2 for Mixed Models
#
#   Conditional R2: 0.544
#      Marginal R2: 0.025
# Correlation matrix not shown by default, as p = 32 > 12.
# Use print(summary(M1), correlation=TRUE)  or
#     vcov(summary(M1))        if you need it

# %% [markdown]
# ## 2.3 Interventions’ Impact on Social Media Sharing.

# %%
#deal with missing data
df_share = df.dropna(subset=["SHAREcc"])

df_share['condName'] = df_share['condName'].replace(['Control'], 'aControl')

# %Rpush df_share

# %%
# %%R
#
# df_share$Ind_score <- scale(df_share$Ind_score)
# #this code rescales the predictor variable to address large eigenvalues
#
# M1 <- glmer(SHAREcc ~ condName*Ind_score + (1 | Country),
#             family = binomial,
#             data = df_share,
#             control = glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 100000)))
# #this code changes the optimizer to address model convergence: lme4 uses "bobyqa" by default for GLMMs, but try others like "Nelder_Mead" or "L-BFGS-B".
# print(summary(M1))
#
# #rsq <- r2(M1) #marginal and conditional R² values
# #print(rsq)
#
# # Calculate Cohen's d
# cohens_d <- lme.dscore(M1, data = df_share, type = "lme4")
# print(cohens_d)
#
# write.csv(coef(summary(M1)), "coefficients_sharescaled.csv") #export coefficients to csv
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: SHAREcc ~ condName * Ind_score + (1 | Country)
#    Data: df_share
# Control: glmerControl(optimizer = "bobyqa", optCtrl = list(maxfun = 1e+05))
#
#      AIC      BIC   logLik deviance df.resid
#  51806.8  52023.9 -25878.4  51756.8    43705
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.2714 -0.7429  0.3769  0.7827  2.5035
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  Country (Intercept) 0.9791   0.9895
# Number of obs: 43730, groups:  Country, 62
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                        -0.20634    0.14300  -1.443 0.149046
# condNameBindingMoral                0.19930    0.05063   3.937 8.27e-05 ***
# condNameCollectAction               0.41270    0.05147   8.019 1.07e-15 ***
# condNameDynamicNorm                 0.32194    0.05098   6.315 2.70e-10 ***
# condNameFutureSelfCont              0.31761    0.05391   5.892 3.82e-09 ***
# condNameLetterFutureGen             0.39275    0.05468   7.183 6.83e-13 ***
# condNameNegativeEmotions            0.49900    0.05190   9.616  < 2e-16 ***
# condNamePluralIgnorance             0.09471    0.05047   1.876 0.060603 .
# condNamePsychDistance               0.34167    0.05275   6.477 9.34e-11 ***
# condNameSciConsens                  0.18372    0.05028   3.654 0.000258 ***
# condNameSystemJust                  0.24477    0.05081   4.817 1.46e-06 ***
# condNameWorkTogetherNorm            0.24780    0.05046   4.911 9.07e-07 ***
# Ind_score                          -0.54948    0.14290  -3.845 0.000120 ***
# condNameBindingMoral:Ind_score     -0.06216    0.05077  -1.224 0.220811
# condNameCollectAction:Ind_score    -0.13864    0.05222  -2.655 0.007937 **
# condNameDynamicNorm:Ind_score      -0.11284    0.05172  -2.182 0.029126 *
# condNameFutureSelfCont:Ind_score   -0.06536    0.05442  -1.201 0.229766
# condNameLetterFutureGen:Ind_score   0.00877    0.05563   0.158 0.874741
# condNameNegativeEmotions:Ind_score -0.16205    0.05282  -3.068 0.002156 **
# condNamePluralIgnorance:Ind_score  -0.04270    0.05091  -0.839 0.401597
# condNamePsychDistance:Ind_score    -0.03022    0.05274  -0.573 0.566711
# condNameSciConsens:Ind_score       -0.05926    0.05072  -1.168 0.242664
# condNameSystemJust:Ind_score       -0.07652    0.05132  -1.491 0.135921
# condNameWorkTogetherNorm:Ind_score -0.14192    0.05094  -2.786 0.005337 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                                             t          df            d
# condNameBindingMoral                3.8385547 43649.27294  0.036745928
# condNameCollectAction               7.7543751 43647.72610  0.074232825
# condNameDynamicNorm                 6.1096751 43648.50135  0.058487552
# condNameFutureSelfCont              5.8172278 43647.79384  0.055688422
# condNameLetterFutureGen             7.2850647 43648.37001  0.069739590
# condNameNegativeEmotions            9.3156236 43647.92884  0.089178488
# condNamePluralIgnorance             1.7759984 43649.02033  0.017001425
# condNamePsychDistance               6.5032083 43649.57418  0.062254057
# condNameSciConsens                  3.5666842 43647.75827  0.034143944
# condNameSystemJust                  4.6899907 43648.62890  0.044896933
# condNameWorkTogetherNorm            4.6151420 43649.24768  0.044180099
# Ind_score                          -3.8412862    66.65982 -0.940967472
# condNameBindingMoral:Ind_score     -0.8168410 43648.89617 -0.007819534
# condNameCollectAction:Ind_score    -1.6667125 43647.70295 -0.015955485
# condNameDynamicNorm:Ind_score      -1.4573943 43648.00988 -0.013951627
# condNameFutureSelfCont:Ind_score   -0.5422092 43647.49395 -0.005190596
# condNameLetterFutureGen:Ind_score   0.9430109 43648.44820  0.009027392
# condNameNegativeEmotions:Ind_score -1.8249898 43647.48241 -0.017470722
# condNamePluralIgnorance:Ind_score  -0.6321111 43649.03333 -0.006051125
# condNamePsychDistance:Ind_score     0.1424025 43648.30730  0.001363214
# condNameSciConsens:Ind_score       -0.8007867 43647.55377 -0.007665966
# condNameSystemJust:Ind_score       -0.9737725 43648.16494 -0.009321901
# condNameWorkTogetherNorm:Ind_score -2.2326681 43649.90842 -0.021372853
# Correlation matrix not shown by default, as p = 24 > 12.
# Use print(summary(M1), correlation=TRUE)  or
#     vcov(summary(M1))        if you need it

# %% [markdown]
# ## 2.4 Interventions’ Impact on Behaviors.

# %%
#deal with missing data
df_WEPT = df.dropna(subset=["WEPTcc"])

df_WEPT['condName'] = df_WEPT['condName'].replace(['Control'], 'aControl')

# %Rpush df_WEPT

# %%
# %%R
#
# df_WEPT$Ind_score <- scale(df_WEPT$Ind_score)
# #this code rescales the predictor variable to address large eigenvalues
#
# M <- clmm(as.factor(WEPTcc) ~ condName*Ind_score + (1|Country), data = df_WEPT, threshold = "equidistant")
# #summary(M)
# print(summary(M))
#
# # Extract fixed effects coefficients directly
# model_coef <- coef(M)
#
# # Calculate odds ratios for fixed effects
# odds_ratios <- exp(model_coef)
#
# #write.csv(coef(summary(M)), "coefficients_weptscaled.csv") #export coefficients to csv

# %%
# %%R
#
# #convert odds ratio to d score
# oddsratio_to_d(odds_ratios)
